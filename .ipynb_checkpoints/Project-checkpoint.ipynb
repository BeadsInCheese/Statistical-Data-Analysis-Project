# %%
import pandas as pd
import scipy
import numpy

# %%
variables = ["kohde","jasen","pvknro","sp","IKAL1","ASALUE","V1","V21","V32","V40","H1a_A","H1h_A"]
#Documentation in habits.text
data=pd.read_csv("habits.data",delimiter=";",na_values="?")

# %%
#remove extra variables
data=data[variables]

# %%
data.rename(columns={'pvknro':'day of week','sp': 'sex', 'IKAL1': 'age group', 'ASALUE': 'living environment', 'V1': 'working', 'V21': 'childcare', 'V32': 'sleeping', 'V33': 'dining', 'V40': 'studying in school', 'H1a_A': 'cinema', 'H1h_A': 'library'}, inplace=True)

# %%
data.keys()
# Out:
# Index(['kohde', 'jasen', 'day of week', 'sex', 'age group',
#        'living environment', 'working', 'childcare', 'sleeping',
#        'studying in school', 'cinema', 'library'],
#       dtype='object')

# %%
data["cinema"]=data["cinema"].astype("category")
data['cinema'] = data['cinema'].cat.rename_categories({ 1.0:'visited',  2.0:'not visited'})
data["library"]=data["library"].astype("category")
data['library'] = data['library'].cat.rename_categories({ 1.0:'visited',  2.0:'not visited',None:'unknown'})
data["living environment"]=data["living environment"].astype("category")
data["sex"]=data["sex"].astype("category")
data['sex'] = data['sex'].cat.rename_categories({ 1.0:'male',  2.0:'female', })
data['living environment'] = data['living environment'].cat.rename_categories({ 1.0:'city',  2.0:'munipality',  3.0:'rural'})

data["day of week"]=data["day of week"].astype("category")
data['day of week'] = data['day of week'].cat.rename_categories({ 1.0:'working day',  2.0:'weekend'})


data["age group"]=data["age group"].astype("category")
data['age group'] = data['age group'].cat.rename_categories({ 1.0:'10-14',  2.0:'15-19',3.0:'20-24 ', 4.0:'25-34 ',  5.0:'35-44',6.0:'45-54 ',7.0:'55-64 ',  8.0:'65-74 ', 9.0:'75-',})
data[data.notna()]
data.dtypes
# Out:
# kohde                    int64
# jasen                    int64
# day of week           category
# sex                   category
# age group             category
# living environment    category
# working                 object
# childcare               object
# sleeping                object
# studying in school      object
# cinema                category
# library               category
# dtype: object

# %%
data[data.notna()]
data[100:200]
# Out:
#      kohde  jasen  day of week     sex age group living environment working  \
# 100  50491      1      weekend    male       75-               city       0
# 101  50497      2  working day  female    45-54               rural       0
# 102  50499      2      weekend    male       75-              rural       0
# 103  50511      1  working day  female    20-24                city       0
# 104  50519      1  working day  female       75-               city       0
# ..     ...    ...          ...     ...       ...                ...     ...
# 195  50967      1      weekend    male     35-44              rural     470
# 196  50969      1  working day  female    55-64          munipality       0
# 197  50970      2      weekend  female     35-44              rural     390
# 198  50975      1  working day    male     35-44         munipality       0
# 199  50977      1      weekend  female       75-               city       0
#
#     childcare sleeping studying in school       cinema      library
# 100         0      420                  0  not visited  not visited
# 101         0      620                  0  not visited      visited
# 102         0      460                  0  not visited  not visited
# 103         0      650                  0      visited      visited
# 104         0      530                  0  not visited      visited
# ..        ...      ...                ...          ...          ...
# 195         0      410                  0  not visited      visited
# 196         0      480                  0      visited  not visited
# 197        10      460                  0  not visited      visited
# 198         0      440                  0          NaN          NaN
# 199         0      710                  0      visited      visited
#
# [100 rows x 12 columns]

# %%
#nan values what to do with them?

#invalid entrys?
#suspicious values

# %% [markdown]
# <h1>With respect to which activities do men and women differ?<h1>

# %%
data.groupby("sex")["working"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 data.groupby("sex")["working"].print()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\groupby\groupby.py:1363, in GroupBy.__getattr__(self, attr)
#    1360 if attr in self.obj:
#    1361     return self[attr]
# -> 1363 raise AttributeError(
#    1364     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'print'

# %%
data.groupby("sex")["cinema"].count()
# Out:
# sex
# 1    164
# 2    205
# Name: cinema, dtype: int64

# %%
data.groupby("sex")["sleeping"].sum()
# Out:
# sex
# 1    45053072061062048048074042072062009:5058046056...
# 2    43056007:2009:30560190600500460610520640620590...
# Name: sleeping, dtype: object

# %%
data.groupby("sex")["childcare"].sum()

# %%
data.groupby("sex")[data.groupby["cinema"]=="1.0"].count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data.groupby("sex")[data.groupby["cinema"]=="1.0"].count()
#
# TypeError: 'method' object is not subscriptable

# %%
data.groupby("sex")["studying in school"].sum()
# Out:
# sex
# 1    0000000000000:0000000:0000:0000000000000000000...
# 2    0000:0000:00000000000000000004800000000:000000...
# Name: studying in school, dtype: object

# %% [markdown]
# <h1>
#
#
# With respect to which activities do living environments differ?<h1>

# %% [markdown]
# <h1>data cleanup</h1>

# %% [markdown]
# <h1>analysis</h1>
